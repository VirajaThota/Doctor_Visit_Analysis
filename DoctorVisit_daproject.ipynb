# %% [markdown]
# importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# reading the dataset from google drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv("/content/drive/MyDrive/ibm da internship/DoctorVisits_DA.csv")
df.head(15)
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %% [markdown]
# Display the complete information about columns of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %% [markdown]
# Finding the total no. of people based on their illness count

# %%
df["illness"].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %% [markdown]
# Visualise and analyse max, mi, medium income

# %%
y = list(df.income)
plt.boxplot(y)
plt.show()

# %% [markdown]
# Finding out the no. of days of reduced activity of males and females due to illness

# %%
df.groupby(['gender',"reduced"]).mean()
# Out:
# <ipython-input-11-932cfaf6515b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['gender',"reduced"]).mean()
#                  Unnamed: 0    visits       age    income   illness    health
# gender reduced
# female 0        2524.038512  0.229322  0.465755  0.482735  1.462144  1.115098
#        1        1985.768421  0.400000  0.325684  0.542105  2.242105  1.610526
#        2        1622.618182  0.672727  0.391455  0.560182  2.236364  1.781818
#        3         997.311111  1.333333  0.403111  0.516000  2.733333  1.733333
#        4        1237.740741  0.851852  0.458889  0.466667  2.222222  2.074074
#        5        1169.055556  1.444444  0.401667  0.614444  2.222222  2.500000
#        6        1382.545455  1.363636  0.426364  0.622727  2.363636  1.363636
# ...

# %% [markdown]
# Visualising if there is any missing values in the dataset with the help of heat map

# %%
sns.heatmap(df.isnull(), cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %% [markdown]
# Finding out the correlation between variables in the given dataset

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), cbar = True, annot = True, cmap = 'Purples')
# Out:
# <ipython-input-13-285f5bd7b95d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cbar = True, annot = True, cmap = 'Purples')
# <Axes: >

# %% [markdown]
# Analyse income of the patient affects the no. of hospital visits

# %%
plt.figure(figsize=(10,10))
plt.scatter(x = 'income', y = 'visits', data = df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# Count and Visualise no. of females and males affected by illness

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %% [markdown]
# visualise the percentage of people getting govt. heath insurance and private health insurance

# %%
#% of people getting govt Insurance due to Low income

label = ['yes', 'no']
Y = df[df['freepoor']=='yes']
N = df[df['freepoor']=='no']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label, colors=('cornflowerblue','powderblue'))
plt.title("% of people getting govt health Insurance due to low income ")
plt.show()

# %%
#% of people having private Insurance

Y = df[df['private']=='yes']
N = df [df[ 'private']=='no']
x = [Y.shape[0], N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label, colors=('pink','palevioletred'))
plt.title("% of people having private health Insurance")
plt.show()

# %%
#% of people getting govt Insurance due to old age, disability or veteran status

Y = df[df['freerepat']=='yes' ]
N = df[df['freerepat']=='no']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label,  colors=('lightgrey','grey'))
plt.title("% of people getting govt health Insurance due to old age, disability etc")
plt.show()

# %% [markdown]
# Plot a horizontal bar chart to analyze the reduced days of activity due to illneess based on Gender

# %%
db= df.groupby('gender')['reduced'].sum().to_frame().reset_index()
#Creating the bar chart
plt.barh(db['gender'], db['reduced'], color = ['cornflowerblue', 'lightseagreen'])
#Adding the aesthetics
plt.title('Bar Chart')
plt.xlabel('reduced activity')
plt.ylabel('gender')
#Show the plot
plt.show()
